# %%
#Bai1
i = 0
while i <= 100:
    if i % 2 == 1:
        print(i)
    i += 1

# %%
#Bai2
i = 0
while i <= 100:
    if i % 2 == 0 and i%3==0:
        print(i)
    i += 1

# %%
a = int(input(""))
for i in range(1,11):
    print(a,"x",i,"=",a*i)

# %%
n = int(input(""))
print(n*(1+n)//2)

# %%
a = int(input(""))
for i in range(1,a+1):
    if a%i == 0:
        print(i)

# %%
a = int(input(""))
d = 0
for i in range(1,a+1):
    if a%i == 0:
        d+=1
print(d)

# %%
a = int(input(""))
b = int(input(""))
for i in range(1,min(a+1,b+1)):
    if a%i == 0 and b%i==0:
        print(i)

# %%
a = int(input(""))
if a**(1/2) %1==0:
    print(a)

# %%
a = int(input(""))
s = 0
for i in range(1,a):
    if a%i == 0:
        s+=i
print(a==s)

# %%
a = int(input(""))
while a<=0:
    a = int(input("Nhap lai:"))
print("Right")

# %%
n = int(input(""))
k = 0
i = 1
while k<=n:
    k+=i
    i+=1
print(k)
