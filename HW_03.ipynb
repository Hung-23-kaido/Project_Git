# %%
#W3A2
a = int(input(""))
b = int(input(""))
a = a^b
b = a^b
a = a^b
print(a,";",b)

# %%
#W3A3
a = int(input(""))
if a & (a-1) == 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A4
m = int(input(""))
n = int(input(""))
print(int(m/n))

# %%
#W3A5
m = int(input(""))
n = int(input(""))
print(round(m/n))

# %%
#W3A6
a = int(input(""))
if a % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
#W3A7
a = int(input(""))
b = int(input(""))
if a*b and a<0:
    print("Yes")
else:
    print("No")

# %%
#W3A8
a = str(input(""))
b = str(input(""))
print(len(a)>len(b))

# %%
#W3A9
a = int(input(""))
b = int(input(""))
c = int(input(""))
lis = [a,b,c].sort()
if lis[0] + lis[1] >= lis[2]:
    print("Yes")
else:
    print("No")

# %%
#W3A10
a = int(input(""))
b = int(input(""))
c = int(input(""))
d = int(input(""))
print(max(a,b,c,d))

# %%
#W3A11
a = int(input(""))
b = int(input(""))
c = int(input(""))
lis = [a,b,c].sort()
if lis[0] + lis[1] >= lis[2]:
    if lis[0] == lis[1]:
        if lis[1] == lis[2]:
            print("Tam giac deu")
        else:
            print("Tam giac can")
    else:
        print("Tam giac thuong")
else:
    print("Khong phai tam giac")

# %%
#W3A12
n = int(input(""))
if (n%4==0 and n%100 != 0) or (n%400):
    print("Yes")
else:
    print("No")

# %%
#W3A14
a = int(input(""))
b = int(input(""))
if a == 0:
    if b == 0:
        print("Vo so nghiem")
    else:
        print("Vo nghiem")
else:
    print(round(-1*b/a,2))

# %%
#W3A15
av = int(input(""))
if av >= 8:
    print("Gioi")
elif av >= 6.5:
    print("Kha")
elif av >= 5:
    print("Trung binh")
else:
    print("Yeu")

# %%
#W3A16
a = float(input(""))
interger = a//1
tp = str(a%1)
if int(tp[2]) >= 5:
    print(interger,interger+1,interger+1)
else:
    print(interger,interger+1,interger)
# Out:
# 4.0

# %%
#W3A17
a = int(input(""))
b = int(input(""))
c = int(input(""))
d = int(input(""))
cb = b/a
if cb%1 == 0:
    if b*cb == c:
        if c*cb == d:
            print("Yes")
        else:
            print("No")
    else: print("No")
else:
    print("No")
# Out:
# Yes
